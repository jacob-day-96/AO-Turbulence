# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '/Users/jacob/Documents/Hawaii Research Project/master_files/master_file.fits'
hdul = fits.open(file)
data = hdul[1].data

midpoint_time = data['midpoint_time']
dimm_time = data['dimm_time']
mass_time = data['mass_time']
deltaT = data['deltaT']
dimm_values = data['dimm_value']
mass_values = data['mass_value']
CFHT_time = data['CFHT_time']
CFHT_windspeed = data['CFHT_windspeed']
CFHT_wind_direction = data['CFHT_wind_direction']
CFHT_temp = data['CFHT_temp']
CFHT_humidity = data['CFHT_humidity']
CFHT_pressure = data['CFHT_pressure']
CFHT_deltaT = data['CFHT_deltaT']
ground_layer_values = data['seeing_gl']
MP_year = data['MP_year']
MP_month = data['MP_month']
MP_day = data['MP_day']
MP_hour = data['MP_hour']

# %%
# Wind Speed
jan_values_windspd_month = CFHT_windspeed[MP_month == 1]
feb_values_windspd_month = CFHT_windspeed[MP_month == 2]
mar_values_windspd_month = CFHT_windspeed[MP_month == 3]
apr_values_windspd_month = CFHT_windspeed[MP_month == 4]
may_values_windspd_month = CFHT_windspeed[MP_month == 5]
jun_values_windspd_month = CFHT_windspeed[MP_month == 6]
jul_values_windspd_month = CFHT_windspeed[MP_month == 7]
aug_values_windspd_month = CFHT_windspeed[MP_month == 8]
sep_values_windspd_month = CFHT_windspeed[MP_month == 9]
oct_values_windspd_month = CFHT_windspeed[MP_month == 10]
nov_values_windspd_month = CFHT_windspeed[MP_month == 11]
dec_values_windspd_month = CFHT_windspeed[MP_month == 12]

windspd_month_to_plot = [jan_values_windspd_month, feb_values_windspd_month, mar_values_windspd_month, 
                         apr_values_windspd_month, may_values_windspd_month, jun_values_windspd_month, 
                         jul_values_windspd_month, aug_values_windspd_month, sep_values_windspd_month, 
                         oct_values_windspd_month, nov_values_windspd_month, dec_values_windspd_month]

yr2009_windspd = CFHT_windspeed[MP_year == 2009]
yr2010_windspd = CFHT_windspeed[MP_year == 2010]
yr2011_windspd = CFHT_windspeed[MP_year == 2011]
yr2012_windspd = CFHT_windspeed[MP_year == 2012]
yr2013_windspd = CFHT_windspeed[MP_year == 2013]
yr2014_windspd = CFHT_windspeed[MP_year == 2014]
yr2015_windspd = CFHT_windspeed[MP_year == 2015]
yr2016_windspd = CFHT_windspeed[MP_year == 2016]
yr2017_windspd = CFHT_windspeed[MP_year == 2017]
yr2018_windspd = CFHT_windspeed[MP_year == 2018]
yr2019_windspd = CFHT_windspeed[MP_year == 2019]
yr2020_windspd = CFHT_windspeed[MP_year == 2020]
yr2021_windspd = CFHT_windspeed[MP_year == 2021]
yr2022_windspd = CFHT_windspeed[MP_year == 2022]
yr2023_windspd = CFHT_windspeed[MP_year == 2023]
yr2024_windspd = CFHT_windspeed[MP_year == 2024]
yr2025_windspd = CFHT_windspeed[MP_year == 2025]

windspd_year_to_plot = [yr2009_windspd, yr2010_windspd, yr2011_windspd, yr2012_windspd, 
                        yr2013_windspd, yr2014_windspd, yr2015_windspd, yr2016_windspd, 
                        yr2017_windspd, yr2018_windspd, yr2019_windspd, yr2020_windspd,
                        yr2021_windspd, yr2022_windspd, yr2023_windspd, yr2024_windspd,
                        yr2025_windspd]
#----------------------------------------------------------------------------------------------

# Wind Direction
jan_values_winddir_month = CFHT_wind_direction[MP_month == 1]
feb_values_winddir_month = CFHT_wind_direction[MP_month == 2]
mar_values_winddir_month = CFHT_wind_direction[MP_month == 3]
apr_values_winddir_month = CFHT_wind_direction[MP_month == 4]
may_values_winddir_month = CFHT_wind_direction[MP_month == 5]
jun_values_winddir_month = CFHT_wind_direction[MP_month == 6]
jul_values_winddir_month = CFHT_wind_direction[MP_month == 7]
aug_values_winddir_month = CFHT_wind_direction[MP_month == 8]
sep_values_winddir_month = CFHT_wind_direction[MP_month == 9]
oct_values_winddir_month = CFHT_wind_direction[MP_month == 10]
nov_values_winddir_month = CFHT_wind_direction[MP_month == 11]
dec_values_winddir_month = CFHT_wind_direction[MP_month == 12]

winddir_month_to_plot = [jan_values_winddir_month, feb_values_winddir_month, mar_values_winddir_month, 
                         apr_values_winddir_month, may_values_winddir_month, jun_values_winddir_month, 
                         jul_values_winddir_month, aug_values_winddir_month, sep_values_winddir_month, 
                         oct_values_winddir_month, nov_values_winddir_month, dec_values_winddir_month]

yr2009_winddir = CFHT_wind_direction[MP_year == 2009]
yr2010_winddir = CFHT_wind_direction[MP_year == 2010]
yr2011_winddir = CFHT_wind_direction[MP_year == 2011]
yr2012_winddir = CFHT_wind_direction[MP_year == 2012]
yr2013_winddir = CFHT_wind_direction[MP_year == 2013]
yr2014_winddir = CFHT_wind_direction[MP_year == 2014]
yr2015_winddir = CFHT_wind_direction[MP_year == 2015]
yr2016_winddir = CFHT_wind_direction[MP_year == 2016]
yr2017_winddir = CFHT_wind_direction[MP_year == 2017]
yr2018_winddir = CFHT_wind_direction[MP_year == 2018]
yr2019_winddir = CFHT_wind_direction[MP_year == 2019]
yr2020_winddir = CFHT_wind_direction[MP_year == 2020]
yr2021_winddir = CFHT_wind_direction[MP_year == 2021]
yr2022_winddir = CFHT_wind_direction[MP_year == 2022]
yr2023_winddir = CFHT_wind_direction[MP_year == 2023]
yr2024_winddir = CFHT_wind_direction[MP_year == 2024]
yr2025_winddir = CFHT_wind_direction[MP_year == 2025]

winddir_year_to_plot = [yr2009_winddir, yr2010_winddir, yr2011_winddir, yr2012_winddir, 
                        yr2013_winddir, yr2014_winddir, yr2015_winddir, yr2016_winddir, 
                        yr2017_winddir, yr2018_winddir, yr2019_winddir, yr2020_winddir,
                        yr2021_winddir, yr2022_winddir, yr2023_winddir, yr2024_winddir,
                        yr2025_winddir]
#----------------------------------------------------------------------------------------------

# Wind Temperature
jan_values_windtemp_month = CFHT_temp[MP_month == 1]
feb_values_windtemp_month = CFHT_temp[MP_month == 2]
mar_values_windtemp_month = CFHT_temp[MP_month == 3]
apr_values_windtemp_month = CFHT_temp[MP_month == 4]
may_values_windtemp_month = CFHT_temp[MP_month == 5]
jun_values_windtemp_month = CFHT_temp[MP_month == 6]
jul_values_windtemp_month = CFHT_temp[MP_month == 7]
aug_values_windtemp_month = CFHT_temp[MP_month == 8]
sep_values_windtemp_month = CFHT_temp[MP_month == 9]
oct_values_windtemp_month = CFHT_temp[MP_month == 10]
nov_values_windtemp_month = CFHT_temp[MP_month == 11]
dec_values_windtemp_month = CFHT_temp[MP_month == 12]

windtemp_month_to_plot = [jan_values_windtemp_month, feb_values_windtemp_month, mar_values_windtemp_month, 
                          apr_values_windtemp_month, may_values_windtemp_month, jun_values_windtemp_month, 
                          jul_values_windtemp_month, aug_values_windtemp_month, sep_values_windtemp_month, 
                          oct_values_windtemp_month, nov_values_windtemp_month, dec_values_windtemp_month]

yr2009_windtemp = CFHT_temp[MP_year == 2009]
yr2010_windtemp = CFHT_temp[MP_year == 2010]
yr2011_windtemp = CFHT_temp[MP_year == 2011]
yr2012_windtemp = CFHT_temp[MP_year == 2012]
yr2013_windtemp = CFHT_temp[MP_year == 2013]
yr2014_windtemp = CFHT_temp[MP_year == 2014]
yr2015_windtemp = CFHT_temp[MP_year == 2015]
yr2016_windtemp = CFHT_temp[MP_year == 2016]
yr2017_windtemp = CFHT_temp[MP_year == 2017]
yr2018_windtemp = CFHT_temp[MP_year == 2018]
yr2019_windtemp = CFHT_temp[MP_year == 2019]
yr2020_windtemp = CFHT_temp[MP_year == 2020]
yr2021_windtemp = CFHT_temp[MP_year == 2021]
yr2022_windtemp = CFHT_temp[MP_year == 2022]
yr2023_windtemp = CFHT_temp[MP_year == 2023]
yr2024_windtemp = CFHT_temp[MP_year == 2024]
yr2025_windtemp = CFHT_temp[MP_year == 2025]

windtemp_year_to_plot = [yr2009_windtemp, yr2010_windtemp, yr2011_windtemp, yr2012_windtemp, 
                         yr2013_windtemp, yr2014_windtemp, yr2015_windtemp, yr2016_windtemp, 
                         yr2017_windtemp, yr2018_windtemp, yr2019_windtemp, yr2020_windtemp,
                         yr2021_windtemp, yr2022_windtemp, yr2023_windtemp, yr2024_windtemp,
                         yr2025_windtemp]
#----------------------------------------------------------------------------------------------

# Wind Pressure
jan_values_windpress_month = CFHT_pressure[MP_month == 1]
feb_values_windpress_month = CFHT_pressure[MP_month == 2]
mar_values_windpress_month = CFHT_pressure[MP_month == 3]
apr_values_windpress_month = CFHT_pressure[MP_month == 4]
may_values_windpress_month = CFHT_pressure[MP_month == 5]
jun_values_windpress_month = CFHT_pressure[MP_month == 6]
jul_values_windpress_month = CFHT_pressure[MP_month == 7]
aug_values_windpress_month = CFHT_pressure[MP_month == 8]
sep_values_windpress_month = CFHT_pressure[MP_month == 9]
oct_values_windpress_month = CFHT_pressure[MP_month == 10]
nov_values_windpress_month = CFHT_pressure[MP_month == 11]
dec_values_windpress_month = CFHT_pressure[MP_month == 12]

windpress_month_to_plot = [jan_values_windpress_month, feb_values_windpress_month, mar_values_windpress_month, 
                           apr_values_windpress_month, may_values_windpress_month, jun_values_windpress_month, 
                           jul_values_windpress_month, aug_values_windpress_month, sep_values_windpress_month, 
                           oct_values_windpress_month, nov_values_windpress_month, dec_values_windpress_month]

yr2009_windpress = CFHT_pressure[MP_year == 2009]
yr2010_windpress = CFHT_pressure[MP_year == 2010]
yr2011_windpress = CFHT_pressure[MP_year == 2011]
yr2012_windpress = CFHT_pressure[MP_year == 2012]
yr2013_windpress = CFHT_pressure[MP_year == 2013]
yr2014_windpress = CFHT_pressure[MP_year == 2014]
yr2015_windpress = CFHT_pressure[MP_year == 2015]
yr2016_windpress = CFHT_pressure[MP_year == 2016]
yr2017_windpress = CFHT_pressure[MP_year == 2017]
yr2018_windpress = CFHT_pressure[MP_year == 2018]
yr2019_windpress = CFHT_pressure[MP_year == 2019]
yr2020_windpress = CFHT_pressure[MP_year == 2020]
yr2021_windpress = CFHT_pressure[MP_year == 2021]
yr2022_windpress = CFHT_pressure[MP_year == 2022]
yr2023_windpress = CFHT_pressure[MP_year == 2023]
yr2024_windpress = CFHT_pressure[MP_year == 2024]
yr2025_windpress = CFHT_pressure[MP_year == 2025]

windpress_year_to_plot = [yr2009_windpress, yr2010_windpress, yr2011_windpress, yr2012_windpress, 
                          yr2013_windpress, yr2014_windpress, yr2015_windpress, yr2016_windpress, 
                          yr2017_windpress, yr2018_windpress, yr2019_windpress, yr2020_windpress,
                          yr2021_windpress, yr2022_windpress, yr2023_windpress, yr2024_windpress,
                          yr2025_windpress]
#----------------------------------------------------------------------------------------------

# Ground Layer Seeing
jan_values_gl_month = ground_layer_values[MP_month == 1]
feb_values_gl_month = ground_layer_values[MP_month == 2]
mar_values_gl_month = ground_layer_values[MP_month == 3]
apr_values_gl_month = ground_layer_values[MP_month == 4]
may_values_gl_month = ground_layer_values[MP_month == 5]
jun_values_gl_month = ground_layer_values[MP_month == 6]
jul_values_gl_month = ground_layer_values[MP_month == 7]
aug_values_gl_month = ground_layer_values[MP_month == 8]
sep_values_gl_month = ground_layer_values[MP_month == 9]
oct_values_gl_month = ground_layer_values[MP_month == 10]
nov_values_gl_month = ground_layer_values[MP_month == 11]
dec_values_gl_month = ground_layer_values[MP_month == 12]

gl_month_to_plot = [jan_values_gl_month, feb_values_gl_month, mar_values_gl_month, 
                    apr_values_gl_month, may_values_gl_month, jun_values_gl_month, 
                    jul_values_gl_month, aug_values_gl_month, sep_values_gl_month, 
                    oct_values_gl_month, nov_values_gl_month, dec_values_gl_month]

yr2009_gl = ground_layer_values[MP_year == 2009]
yr2010_gl = ground_layer_values[MP_year == 2010]
yr2011_gl = ground_layer_values[MP_year == 2011]
yr2012_gl = ground_layer_values[MP_year == 2012]
yr2013_gl = ground_layer_values[MP_year == 2013]
yr2014_gl = ground_layer_values[MP_year == 2014]
yr2015_gl = ground_layer_values[MP_year == 2015]
yr2016_gl = ground_layer_values[MP_year == 2016]
yr2017_gl = ground_layer_values[MP_year == 2017]
yr2018_gl = ground_layer_values[MP_year == 2018]
yr2019_gl = ground_layer_values[MP_year == 2019]
yr2020_gl = ground_layer_values[MP_year == 2020]
yr2021_gl = ground_layer_values[MP_year == 2021]
yr2022_gl = ground_layer_values[MP_year == 2022]
yr2023_gl = ground_layer_values[MP_year == 2023]
yr2024_gl = ground_layer_values[MP_year == 2024]
yr2025_gl = ground_layer_values[MP_year == 2025]

gl_year_to_plot = [yr2009_gl, yr2010_gl, yr2011_gl, yr2012_gl, 
                   yr2013_gl, yr2014_gl, yr2015_gl, yr2016_gl, 
                   yr2017_gl, yr2018_gl, yr2019_gl, yr2020_gl,
                   yr2021_gl, yr2022_gl, yr2023_gl, yr2024_gl,
                   yr2025_gl]
#----------------------------------------------------------------------------------------------

# DIMM Values
jan_values_dimm_month = dimm_values[MP_month == 1]
feb_values_dimm_month = dimm_values[MP_month == 2]
mar_values_dimm_month = dimm_values[MP_month == 3]
apr_values_dimm_month = dimm_values[MP_month == 4]
may_values_dimm_month = dimm_values[MP_month == 5]
jun_values_dimm_month = dimm_values[MP_month == 6]
jul_values_dimm_month = dimm_values[MP_month == 7]
aug_values_dimm_month = dimm_values[MP_month == 8]
sep_values_dimm_month = dimm_values[MP_month == 9]
oct_values_dimm_month = dimm_values[MP_month == 10]
nov_values_dimm_month = dimm_values[MP_month == 11]
dec_values_dimm_month = dimm_values[MP_month == 12]

dimm_month_to_plot = [jan_values_dimm_month, feb_values_dimm_month, mar_values_dimm_month, 
                      apr_values_dimm_month, may_values_dimm_month, jun_values_dimm_month, 
                      jul_values_dimm_month, aug_values_dimm_month, sep_values_dimm_month, 
                      oct_values_dimm_month, nov_values_dimm_month, dec_values_dimm_month]

yr2009_dimm = dimm_values[MP_year == 2009]
yr2010_dimm = dimm_values[MP_year == 2010]
yr2011_dimm = dimm_values[MP_year == 2011]
yr2012_dimm = dimm_values[MP_year == 2012]
yr2013_dimm = dimm_values[MP_year == 2013]
yr2014_dimm = dimm_values[MP_year == 2014]
yr2015_dimm = dimm_values[MP_year == 2015]
yr2016_dimm = dimm_values[MP_year == 2016]
yr2017_dimm = dimm_values[MP_year == 2017]
yr2018_dimm = dimm_values[MP_year == 2018]
yr2019_dimm = dimm_values[MP_year == 2019]
yr2020_dimm = dimm_values[MP_year == 2020]
yr2021_dimm = dimm_values[MP_year == 2021]
yr2022_dimm = dimm_values[MP_year == 2022]
yr2023_dimm = dimm_values[MP_year == 2023]
yr2024_dimm = dimm_values[MP_year == 2024]
yr2025_dimm = dimm_values[MP_year == 2025]

dimm_year_to_plot = [yr2009_dimm, yr2010_dimm, yr2011_dimm, yr2012_dimm, 
                     yr2013_dimm, yr2014_dimm, yr2015_dimm, yr2016_dimm, 
                     yr2017_dimm, yr2018_dimm, yr2019_dimm, yr2020_dimm,
                     yr2021_dimm, yr2022_dimm, yr2023_dimm, yr2024_dimm,
                     yr2025_dimm]
#----------------------------------------------------------------------------------------------

# Mass Values
jan_values_mass_month = mass_values[MP_month == 1]
feb_values_mass_month = mass_values[MP_month == 2]
mar_values_mass_month = mass_values[MP_month == 3]
apr_values_mass_month = mass_values[MP_month == 4]
may_values_mass_month = mass_values[MP_month == 5]
jun_values_mass_month = mass_values[MP_month == 6]
jul_values_mass_month = mass_values[MP_month == 7]
aug_values_mass_month = mass_values[MP_month == 8]
sep_values_mass_month = mass_values[MP_month == 9]
oct_values_mass_month = mass_values[MP_month == 10]
nov_values_mass_month = mass_values[MP_month == 11]
dec_values_mass_month = mass_values[MP_month == 12]

mass_month_to_plot = [jan_values_mass_month, feb_values_mass_month, mar_values_mass_month, 
                      apr_values_mass_month, may_values_mass_month, jun_values_mass_month, 
                      jul_values_mass_month, aug_values_mass_month, sep_values_mass_month, 
                      oct_values_mass_month, nov_values_mass_month, dec_values_mass_month]

yr2009_mass = mass_values[MP_year == 2009]
yr2010_mass = mass_values[MP_year == 2010]
yr2011_mass = mass_values[MP_year == 2011]
yr2012_mass = mass_values[MP_year == 2012]
yr2013_mass = mass_values[MP_year == 2013]
yr2014_mass = mass_values[MP_year == 2014]
yr2015_mass = mass_values[MP_year == 2015]
yr2016_mass = mass_values[MP_year == 2016]
yr2017_mass = mass_values[MP_year == 2017]
yr2018_mass = mass_values[MP_year == 2018]
yr2019_mass = mass_values[MP_year == 2019]
yr2020_mass = mass_values[MP_year == 2020]
yr2021_mass = mass_values[MP_year == 2021]
yr2022_mass = mass_values[MP_year == 2022]
yr2023_mass = mass_values[MP_year == 2023]
yr2024_mass = mass_values[MP_year == 2024]
yr2025_mass = mass_values[MP_year == 2025]

mass_year_to_plot = [yr2009_mass, yr2010_mass, yr2011_mass, yr2012_mass, 
                     yr2013_mass, yr2014_mass, yr2015_mass, yr2016_mass, 
                     yr2017_mass, yr2018_mass, yr2019_mass, yr2020_mass,
                     yr2021_mass, yr2022_mass, yr2023_mass, yr2024_mass,
                     yr2025_mass]
#----------------------------------------------------------------------------------------------


months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]
years = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", 
         "2018", "2019", "2020", "2021", "2022", "2023", "2024", "2025"]

# %% [markdown]
# ### Wind Speed

# %%
# Wind Speed By Month
plt.figure(figsize=(10, 6))
plt.boxplot(windspd_month_to_plot, labels=months, showfliers=True)

plt.title('Wind Speed (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Wind Speed (m/s)', fontsize = 14)
plt.tight_layout()
plt.show()

# Wind Speed By Year
plt.figure(figsize=(10, 6))
plt.boxplot(windspd_year_to_plot, labels=years, showfliers=True)

plt.title('Wind Speed (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Wind Speed (m/s)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wind Direction

# %%
# Wind Direction By Month
plt.figure(figsize=(10, 6))
plt.boxplot(winddir_month_to_plot, labels=months, showfliers=True)

plt.title('Wind Direction (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Wind Direction (Dec)', fontsize = 14)
plt.tight_layout()
plt.show()

# Wind Direction By Year
plt.figure(figsize=(10, 6))
plt.boxplot(winddir_year_to_plot, labels=years, showfliers=True)

plt.title('Wind Direction (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Wind Direction (Dec)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wind Temperature

# %%
# Wind Temperature By Month
plt.figure(figsize=(10, 6))
plt.boxplot(windtemp_month_to_plot, labels=months, showfliers=True)

plt.title('Wind Temperature (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Wind Temperature (°C)', fontsize = 14)
plt.tight_layout()
plt.show()

# Wind Temperature By Year
plt.figure(figsize=(10, 6))
plt.boxplot(windtemp_year_to_plot, labels=years, showfliers=True)

plt.title('Wind Temperature (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Wind Temperature (°C)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Wind Pressure

# %%
# Wind Pressure By Month
plt.figure(figsize=(10, 6))
plt.boxplot(windpress_month_to_plot, labels=months, showfliers=True)

plt.title('Wind Pressure (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Wind Pressure (Pa)', fontsize = 14)
plt.tight_layout()
plt.show()

# Wind Pressure By Year
plt.figure(figsize=(10, 6))
plt.boxplot(windpress_year_to_plot, labels=years, showfliers=True)

plt.title('Wind Pressure (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Wind Pressure (Pa)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ground Layer Seeing

# %%
# Ground Layer Seeing By Month
plt.figure(figsize=(10, 6))
plt.boxplot(gl_month_to_plot, labels=months, showfliers=True)

plt.title('Ground Layer Seeing (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Ground Layer Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()

# Ground Layer Seeing By Year
plt.figure(figsize=(10, 6))
plt.boxplot(gl_year_to_plot, labels=years, showfliers=True)

plt.title('Ground Layer Seeing (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Ground Layer Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DIMM Seeing

# %%
# DIMM Seeing By Month
plt.figure(figsize=(10, 6))
plt.boxplot(dimm_month_to_plot, labels=months, showfliers=True)

plt.title('DIMM Seeing (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('DIMM Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()

# DIMM Seeing By Year
plt.figure(figsize=(10, 6))
plt.boxplot(dimm_year_to_plot, labels=years, showfliers=True)

plt.title('DIMM Seeing (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('DIMM Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### MASS Seeing

# %%
# MASS Seeing By Month
plt.figure(figsize=(10, 6))
plt.boxplot(mass_month_to_plot, labels=months, showfliers=True)

plt.title('MASS Seeing (By Month)', fontsize = 16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('MASS Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()

# MASS Seeing By Year
plt.figure(figsize=(10, 6))
plt.boxplot(mass_year_to_plot, labels=years, showfliers=True)

plt.title('MASS Seeing (By Year)', fontsize = 16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('MASS Seeing (arcsec)', fontsize = 14)
plt.tight_layout()
plt.show()
