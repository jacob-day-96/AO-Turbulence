# %%
# Data visualization notebook that performs binned statistical analysis
# using the `plot_median_per_bin_doane()` function from `plot_functions.ipynb`,
# which applies Doane’s rule for adaptive histogram binning.
#
# The notebook bins a selected parameter from the master dataset and
# computes the median value within each bin to capture central trends
# while reducing sensitivity to outliers.
#
# The resulting visualization plots binned medians to reveal how the
# chosen parameter evolves across its distribution and to highlight
# non-linear structure that may be obscured in raw scatter or histogram
# views.

# %run plot_functions.ipynb

# %%
file = '/Users/jacob/Documents/Hawaii Research Project/master_file.fits'
hdul = fits.open(file)
data = hdul[1].data

dimm_values = data['dimm_val']
mass_values = data['mass_val']
ground_layer_values = data['ground_layer']
CFHT_windspeed = data['wind_speed']
CFHT_wind_direction = data['wind_dir']
CFHT_temp = data['temp']
CFHT_humidity = data['humidity']
CFHT_pressure = data['pressure']

# %% [markdown]
# ## DIMM Seeing VS. CFHT Data

# %% [markdown]
# ### Wind Speed

# %%
plot_median_per_bin_doane(CFHT_windspeed, dimm_values, 'CFHT Wind Speed', 'Median DIMM Seeing Value')

# %% [markdown]
# ### Wind Direction

# %%
plot_median_per_bin_doane(CFHT_wind_direction, dimm_values, 'CFHT Wind Direction', 'Median DIMM Seeing Value')

# %% [markdown]
# ### Wind Temperature

# %%
plot_median_per_bin_doane(CFHT_temp, dimm_values, 'CFHT Wind Temperature', 'Median DIMM Seeing Value')

# %% [markdown]
# ### Wind Humidity

# %%
plot_median_per_bin_doane(CFHT_humidity, dimm_values, 'CFHT Wind Humidity', 'Median DIMM Seeing Value')

# %% [markdown]
# ### Wind Pressure

# %%
plot_median_per_bin_doane(CFHT_pressure, dimm_values, 'CFHT Wind Pressure', 'Median DIMM Seeing Value')

# %% [markdown]
# ## MASS Seeing VS. CFHT Data

# %% [markdown]
# ### Wind Speed

# %%
plot_median_per_bin_doane(CFHT_windspeed, mass_values, 'CFHT Wind Speed', 'Median MASS Seeing Value')

# %% [markdown]
# ### Wind Direction

# %%
plot_median_per_bin_doane(CFHT_wind_direction, mass_values, 'CFHT Wind Direction', 'Median MASS Seeing Value')

# %% [markdown]
# ### Wind Temperature

# %%
plot_median_per_bin_doane(CFHT_temp, mass_values, 'CFHT Wind Temperature', 'Median MASS Seeing Value')

# %% [markdown]
# ### Wind Humidity

# %%
plot_median_per_bin_doane(CFHT_humidity, mass_values, 'CFHT Wind Humidity', 'Median MASS Seeing Value')

# %% [markdown]
# ### Wind Pressure

# %%
plot_median_per_bin_doane(CFHT_pressure, mass_values, 'CFHT Wind Pressure', 'Median MASS Seeing Value')

# %% [markdown]
# ## Ground Layer Seeing VS. CFHT Data

# %% [markdown]
# ### Wind Speed

# %%
plot_median_per_bin_doane(CFHT_windspeed, ground_layer_values, 'CFHT Wind Speed', 'Median Ground Layer Seeing Value')

# %% [markdown]
# ### Wind Direction

# %%
plot_median_per_bin_doane(CFHT_wind_direction, ground_layer_values, 'CFHT Wind Direction', 'Median Ground Layer Seeing Value')

# %% [markdown]
# ### Wind Temperature

# %%
plot_median_per_bin_doane(CFHT_temp, ground_layer_values, 'CFHT Wind Temperature', 'Median Ground Layer Seeing Value')

# %% [markdown]
# ### Wind Humidity

# %%
plot_median_per_bin_doane(CFHT_humidity, ground_layer_values, 'CFHT Wind Humidity', 'Median Ground Layer Seeing Value')

# %% [markdown]
# ### Wind Pressure

# %%
plot_median_per_bin_doane(CFHT_pressure, ground_layer_values, 'CFHT Wind Pressure', 'Median Ground Layer Seeing Value')
