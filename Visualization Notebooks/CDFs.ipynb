# %%
# %run plot_functions.ipynb

# %%
# Data visualization notebook that uses the master dataset to generate
# CDF comparisons for selected parameters using the `cdf_even_odd`,
# `cdf_comparison`, and `cdf_first_second_half` functions from
# `plot_functions.ipynb`.
# These visualizations highlight how parameter distributions differ
# across varying data contexts and time groupings.

file = 'path/to/master_file'
hdul = fits.open(file)
data = hdul[1].data

dimm_values = data['dimm_val']
mass_values = data['mass_val']
ground_layer_values = data['ground_layer']
CFHT_windspeed = data['wind_speed']
CFHT_wind_direction = data['wind_dir']
CFHT_temp = data['temp']
CFHT_humidity = data['humidity']
CFHT_pressure = data['pressure']

# %% [markdown]
# ### Even vs. Odd Rows of Data Column

# %%
cdf_even_odd(dimm_values, 'DIMM')
cdf_even_odd(mass_values, 'MASS')
cdf_even_odd(ground_layer_values, 'Ground Layer')
# Out:
# KS Test: D = 0.002, p = 0.982
# KS Test: D = 0.003, p = 0.416
# KS Test: D = 0.002, p = 0.974

# %% [markdown]
# ### Compare Two Different Columns of Data

# %%
cdf_comparison(dimm_values, mass_values, "DIMM", "MASS")
# Out:
# KS Test: D = 0.568, p = 0.000

# %% [markdown]
# ### First vs. Second Half of Data Column

# %%
cdf_first_second_half(dimm_values, "DIMM")
cdf_first_second_half(mass_values, "MASS")
cdf_first_second_half(ground_layer_values, "Ground Layer")
# Out:
# KS Test: D = 0.011, p = 0.000
# KS Test: D = 0.011, p = 0.000
# KS Test: D = 0.007, p = 0.001
